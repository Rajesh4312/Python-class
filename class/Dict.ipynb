# %%
x={"A":10,"B":9,"C":8}
x.values()
# Out:
# dict_values([10, 9, 8])

# %%
x={"A":10,"B":9,"C":8}
a={"B":7}
x.update(a)
print(x)
# Out:
# {'A': 10, 'B': 7, 'C': 8}

# %%
x={"A":10,"B":9,"C":8}
x["B"]=7
x
# Out:
# {'A': 10, 'B': 7, 'C': 8}

# %%
x={"A":10,"B":9,"C":8}
del(x)
x
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 3
#       1 x={"A":10,"B":9,"C":8}
#       2 del(x)
# ----> 3 x
#
# NameError: name 'x' is not defined
