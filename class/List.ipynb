# %%
l=["1","2","3","4","5","6","hi"]
l[0]=2
print(l)
# Out:
# [2, '2', '3', '4', '5', '6', 'hi']

# %%
l=["hi","2","hello",75]
l[1]=36
l.remove("hello")
l.append(86)
print(l)
# Out:
# ['hi', 36, 75, 86]

# %%
num="madam"
nu=num[::-1]
if num == nu:
    print("True")
# Out:
# True
