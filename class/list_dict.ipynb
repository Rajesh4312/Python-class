# %%
l1=["apple","banana","cherry"]
l2=[1,2,3]
result=dict(zip(l1,l2))
print(result)
# Out:
# {'apple': 1, 'banana': 2, 'cherry': 3}

# %%
l1 = ["apple", "banana", "cherry"]
l2 = [1, 2, 3]

result = {}

for i in range(len(l1)):
    result[l1[i]] = l2[i]

print(result)
# Out:
# {'apple': 1, 'banana': 2, 'cherry': 3}
