# %%
l=[1,2,3,4,5,6,7,8]
l[2:5]="hi"
l
# Out:
# [1, 2, 'h', 'i', 6, 7, 8]

# %%
d={2,3,4,6}
d.add(86)
d
# Out:
# {2, 3, 4, 6, 86}

# %%
t={"hi":7,"hello":8}
t["hello"]=10
t
# Out:
# {'hi': 7, 'hello': 10}

# %%
t={"hi":7,"hello":8}
t.update({"hello":10})
t
# Out:
# {'hi': 7, 'hello': 10}

# %%
l = [1, 2, [5, 6, [8, 7, 8], 10], 12]
print(l[2][3])
# Out:
# 10
