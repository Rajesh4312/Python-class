# %%
k=5
print(type(k))
# Out:
# <class 'int'>

# %%
k="Rajesh"
print(type(k))
# Out:
# <class 'str'>

# %%
k=9.2
print(type(k))
# Out:
# <class 'float'>

# %%
k=True
print(type(k))
# Out:
# <class 'bool'>

# %%
k=1+2j
print(type(k))
# Out:
# <class 'complex'>

# %%
k1=5
k
# Out:
# (1+2j)

# %%
k3=float(k1)
print(k)
# Out:
# 5.0

# %%
k=complex(k1)
print(type(k))
# Out:
# <class 'complex'>

# %%
k2=int(k)
print(k)
# Out:
# 5

# %%
print(type(k))
# Out:
# <class 'int'>
