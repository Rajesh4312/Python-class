# %%
for i in range(2,13,2):
    print(i)
# Out:
# 2
# 4
# 6
# 8
# 10
# 12

# %%
for i in range(2,13,2):
    pass

# %%
for i in range(2,13,2):
    if i == 4:
        continue
    print(i)
# Out:
# 2
# 6
# 8
# 10
# 12

# %%
for i in range(2,13,2):
    if i == 4:
        break
    print(i)
# Out:
# 2

# %%
# set

l={2,1,2,3,4,5,6}
for i in l:
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6

# %%
# set
l={6,5,6,6,2}
for i in l:
    print(i)
# Out:
# 2
# 5
# 6

# %%
k=[1,2,4,56]
l=[]
for i in k:
    if i % 2 !=0:
       l.append(i)

print(l)
# Out:
# [1]

# %%
l=[]
l.append(6)
print(l)
# Out:
# [6]
