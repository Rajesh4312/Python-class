# %%
def ram(a,b):
    print(a+b)
ram(5,6)
# Out:
# 11

# %%
def ram(a,b):
    print(a+b)
a=int(input())
b=int(input())
ram(a,b)
# Out:
#  7
#  8
# 15

# %%
def ram(a,b):
    c=a+b
    d=a-b
    return c

k=ram(5,6)
print(k)
# Out:
# None

# %%
a=6
b=7
def add(a,b):
    global c,d
    c=a+b
    d=a-b
    print(c)
def sub(a,b):
    return d
add(a,b)
sub(a,b)
# Out:
# 13
# -1
