# %%
i=0
while i <=6 :
    print(i)
    i +=1
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6

# %%
i=50
while i >=30 :
    print(i)
    i -=1
# Out:
# 50
# 49
# 48
# 47
# 46
# 45
# 44
# 43
# 42
# 41
# 40
# 39
# 38
# 37
# 36
# 35
# 34
# 33
# 32
# 31
# 30

# %%
k=[1,3,45,6,889,90]
n=0
for i in k:
    print(f"{i}, index : {n}")
    n+=1
# Out:
# 1, index : 0
# 3, index : 1
# 45, index : 2
# 6, index : 3
# 889, index : 4
# 90, index : 5

# %%
k=[1,3,45,6,889,90]
for i in range(len(k)):
    print(i,k[i])
# Out:
# 0 1
# 1 3
# 2 45
# 3 6
# 4 889
# 5 90

# %%
k=[1,3,45,6,889,90]
l=0
for i in k:
    l +=1
print(l)
# Out:
# 6
