# %%
f=open("new.txt", "r")
k=f.read()
print(k)

# %%
people_numbers = {
    "Arun": 9876543210,
    "Bala": 9876543211,
    "Charan": 9876543212,
    "Divya": 9876543213,
    "Esha": 9876543214,
    "Farhan": 9876543215,
    "Gokul": 9876543216,
    "Hari": 9876543217,
    "Ishaan": 9876543218,
    "Jaya": 9876543219
}
k=len(people_numbers)

while k >0:
    word1=input("Enter a name")
    if word1 in people_numbers:
        print(people_numbers[word1])
    else:
        print("name not found")
# Out:
# Enter a name Arun
# 9876543210
