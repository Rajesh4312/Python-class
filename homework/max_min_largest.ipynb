# %%
l=[3,6,5,2,86,57,9,1]
print(max(l))
# Out:
# 86

# %%
l=[3,6,5,2,86,57,9,1]
print(min(l))
# Out:
# 1

# %%
l=[3,6,5,2,86,57,9,1]
max=l[0]
for num in l:
    if num > max:
        max=num
print(max)
# Out:
# 86

# %%
l=[3,6,5,2,86,57,9,1]
min=l[0]
for num in l:
    if num < min:
        min=num
print(min)
# Out:
# 1

# %%
l=[3,6,5,2,86,57,9,1]
l.sort()
print(l[-2])
# Out:
# 57

# %%
l=[3,6,5,2,86,57,9,1]
l.sort()
print(l[1])
# Out:
# 2

# %%
l=[3,6,5,2,86,57,9,1]
min=l[0]
for num in l:
    if num < min:
        min=num
print(min)
# Out:
# 1
