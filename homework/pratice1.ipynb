# %%
'''a=5
b=6
print(a+b'''

# %%
k,l,m="apple","mango","orange"
print(type(k))
# Out:
# <class 'str'>

# %%
numbers = [10, 20, 30, 40, 50]
numbers.sort()
numbers
# Out:
# [10, 20, 30, 40, 50]

# %%
t = (10, 20, 30, 40, 50)
s=list(t)
print(type(s))
# Out:
# <class 'list'>

# %%
s = {10, 20, 30, 40}
s.discard(60)
s
# Out:
# {10, 20, 30, 40}

# %%
g=4.678
print(type(g))
# Out:
# <class 'float'>

# %%
student = {
    "name": "Raj",
    "age": 20,
    "city": "Chennai"
}


print(student.get("nam"))
# Out:
# Raj

# %%
i=1+2j
print(int(i.real))
print(i.imag)
# Out:
# 1
# 2.0

# %%
n=1+2j
s=str(n)
print(type(s))
# Out:
# <class 'str'>

# %%
k="10"
s=int(k)
print(type(s))
# Out:
# <class 'int'>

# %%
k = "welcome, hi how are you"
k.replace("hi","hello")
# Out:
# 'welcome, hello how are you'

# %%
txt = "hello world"
print(txt.index("z"))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[29], line 2
#       1 txt = "hello world"
# ----> 2 print(txt.index("z"))
#
# ValueError: substring not found

# %%
txt = "hello world"
print(txt.find("z"))
# Out:
# -1

# %%
k="123"
print(k.isdigit)
# Out:
# <built-in method isdigit of str object at 0x0000020154F6F750>

# %%
k="python"
print(k[0::])
# Out:
# python

# %%
b = "Hello, World!"
print(b[:4])
# Out:
# Hell

# %%
b = "Hello, World!"
print(b.split("W"))
# Out:
# ['Hello, ', 'orld!']

# %%
a=11
b=12
print(a|b)
# Out:
# 15

# %%
x =["apple"]
y =["apple"]
z = x
# print(z)
print(x is y)
# Out:
# False

# %%
print(True*False)
# Out:
# 0

# %%
k=[1,2,3,[78,[45,56],89,90],7,8]
print(k[3][2])
# Out:
# 89

# %%
mylist = ["apple", "banana", "carrot"]
print(mylist)
mylist[1]="kiwi"
mylist
# Out:
# ['apple', 'banana', 'carrot']
# ['apple', 'kiwi', 'carrot']

# %%
mylist = ["orange", "mango", "kiwi", "pineapple", "banana"]
mylist.sort()
print(mylist)
# Out:
# ['banana', 'kiwi', 'mango', 'orange', 'pineapple']

# %%
l={"k":1,"k2":3,"j1":7}
for i in l.keys():
    print(i)
# Out:
# k
# k2
# j1

# %%
k=[1,3,45,6,889,90]
for i,j in enumerate(k):
    if i==3:
        print(j)
# Out:
# 6

# %%
k=[1,2,3,4,5]
for index,i in enumerate(k):
    print(index)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
i = 0

while i <= 7:
    pass

print("hi")
