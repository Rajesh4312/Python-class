# %%
# slice
new="hey how are you"
print(new[-6:-2])
# Out:
# re y

# %%
name="Rajesh"
print(name.upper())
print(name.split('a'))
print(name.strip())
print(name.lower())
print(name.capitalize())
# Out:
# RAJESH
# ['R', 'jesh']
# Rajesh
# rajesh
# Rajesh

# %%
# title
words= "hey how are you"
print(words.title())
# Out:
# Hey How Are You

# %%
# replace
words="hello world"
print(words.replace("world","python"))
# Out:
# hello python

# %%
# count
name="banana"
print(name.count("a"))
# Out:
# 3

# %%
# find
name="python"
print(name.find("yt"))
# Out:
# 1
