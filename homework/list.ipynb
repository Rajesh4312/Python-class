# %%
l=["Gova","Orange",2,"Apple",6,"Grapes","Cherry",8,"Banana",9,]
l[2]=4
l.pop()

print(l)
# Out:
# ['Gova', 'Orange', 4, 'Apple', 6, 'Grapes', 'Cherry', 8, 'Banana']

# %%
l1=["Gova","Orange",2,"Apple",6,"Grapes","Cherry",8,"Banana",9,]
l2=[7,"mango",9,"Gova",5]
l1.extend(l2)
print(l1)
# Out:
# ['Gova', 'Orange', 2, 'Apple', 6, 'Grapes', 'Cherry', 8, 'Banana', 9, 7, 'mango', 9, 'Gova', 5]

# %%
l=["Gova","Orange",2,"Apple",6,"Grapes","Cherry",8,"Banana",9,]
# l.remove("Orange")l,l,
print(l)
# Out:
# ['Gova', 2, 'Apple', 6, 'Grapes', 'Cherry', 8, 'Banana', 9]

# %%
l=("orange","gova")
a=list(l)
a[1]=("grapes")
b=tuple(a)
print(b)
# Out:
# ('orange', 'grapes')
