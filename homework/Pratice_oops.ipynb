# %%
class person():
    def __init__(self,name,age):
        self.name=name
        self.age=age
    def display(self):
        print(self.name)
        print(self.age)
class Student(person):
    def __init__(self,name,age,course):
        super().__init__(name,age)
        self.course=course
    def display_info(self):
        print(self.name)
        print(self.age)
        print(self.course)
        
        
name = input()
age=int(input())
course=input()

k= Student(name,age,course)
k.display_info()
# Out:
#  rajesh
#  18
#  cse
# rajesh
# 18
# cse

# %%
class univercity():
    def __init__(self,name,location):
        self.name=name
        self.location=location
    def details(self):
        print(self.name)
        print(self.location)
class collage(univercity):
    def __init__(self,name,location,clg_name):
        super().__init__(name,location)
        self.clg_name=clg_name
    def show(self):
        print(self.clg_name)
class deptment(collage):
    def __init__(self,name,location,clg_name,dept):
        super().__init__(name,location,clg_name)
        self.dept=dept
    def display(self):
        print(self.dept)
name=input()
location=input()
clg_name=input()
dept=input()
l=deptment(name,location,clg_name,dept)
l.details()
l.show()
# Out:
#  rajesh
#  che
#  hhd
#  hdd
# rajesh
# che
# hhd

# %%
class univercity():
    def __init__(self,name,age):
        self.name=name
        self.age=age
    def show(self):
        print(self.name)
        print(self.age)
class collage():
    def __init__(self,clg_name):
        self.clg_name=clg_name
    def display(self):
        print(self.clg_name)
class department(univercity,collage):
    def __init__(self,name,age,clg_name,dept):
        univercity.__init__(self,name,age)
        collage.__init__(self,clg_name)
        self.dept=dept
    def details(self):
        print(self.dept)
name=input()
age=int(input())
dept=input()
k=department(name,age,dept,clg_name)
k.show()
# Out:
#  rajesh
#  17
#  cse
# rajesh
# 17

# %%
class univercity():
    def __init__(self,name,age):
        self.name=name
        self.age=age
    def show(self):
        print(self.name)
        print(self.age)
class collage(univercity):
    def __init__(self,clg_name,name,age):
        super().__init__(name,age)
        self.clg_name=clg_name
    def display(self):
        print(self.clg_name)
class department(univercity):
    def __init__(self,name,age,dept):
        super().__init__(name,age)
        self.dept=dept
    def details(self):
        print(self.dept)
name=input()
age=int(input())
dept=input()
k=department(name,age,dept)
k.show()
# Out:
#  jd
#  9
#  dm
# jd
# 9

# %%
class BankAccount():
    def __init__(self):
        self.__balance=0
    def Deposit(self,amount):
        self.__balance += amount
        print(self.__balance)
    def withdraw(self,amount):
        if amount <= self.__balance:
            self.__balance -=amount
            print("Withdrawn:", amount)
        else:
            print("Insufficient Balance")

    def check_balance(self):
        print("Balance:", self.__balance)
    
acc = BankAccount()

acc.Deposit(5000)
acc.check_balance()

acc.withdraw(2000)
acc.check_balance()
# Out:
# 5000
# Balance: 5000
# Withdrawn: 2000
# Balance: 3000

# %%
class Student():
    def __init__(self):
        self.__marks=0
    def set_marks(self,marks):
        self.__marks=marks
    def get_marks(self):
        return self.__marks
        
a=Student()
a.set_marks(86)
print(a.get_marks())
# Out:
# 86

# %%
class Animal():
    def sound(self):
        print("Animal")
class Dog(Animal):
    def sound(self):
        print("Dog")
class cat(Animal):
    def sound(self):
        print("Dog")
A=Animal()
d=Dog()
A.sound()
d.sound()
# Out:
# Animal
# Dog
