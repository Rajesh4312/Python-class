# %%
l=[1,2,3,4,4,3,2,1,5,6]
k=[]
for i in l:
    if i not in k:
        k.append(i)
print(k)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
l=[1,2,3,4,4,3,2,1,5,6]
k={}
for i in l:
    if i in k:
        k [i]+=1
    else:
        k[i]=1
print(k)
# Out:
# {1: 2, 2: 2, 3: 2, 4: 2, 5: 1, 6: 1}
