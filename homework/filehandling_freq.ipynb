# %%
f=open("data.txt","r")
k=f.read()
words = k.split()
count={}
for i in words:
    if i in count:
        count[i] +=1
    else:
        count[i] =1
print(count)
# Out:
# {'Data': 2, 'science': 4, 'is': 1, 'a': 1, 'powerful': 1, 'field.': 1, 'helps': 2, 'people': 1, 'analyze': 1, 'data': 6, 'and': 3, 'understand': 1, 'data.': 2, 'When': 1, 'we': 2, 'work': 1, 'with': 2, 'science,': 1, 'collect': 1, 'data,': 2, 'clean': 1, 'study': 1, 'Many': 1, 'companies': 1, 'use': 1, 'because': 1, 'them': 1, 'make': 1, 'better': 1, 'decisions.': 1, 'Learning': 1, 'working': 1, 'can': 1, 'create': 1, 'many': 1, 'opportunities': 1, 'in': 1, 'the': 1, 'future.': 1}

# %%
f=open("example.csv",'w')
f.write("Name,Age,Location\n")
f.write("Rajesh,20,viruthai\n")
f.write("dinesh,21,chennai\n")
f.write("Ram,21,madurai\n")
f.close()

# %%
f = open("people.csv", "w")

f.write("name,age,location\n")
f.write("Rajesh,19,Tamil Nadu\n")
f.write("Arun,22,Chennai\n")
f.write("Kumar,25,Madurai\n")

f.close()
