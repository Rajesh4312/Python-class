# %%
# Identity Operators
# a=5
# b=5
# print(a is b)
# a=[1,2]
# b=[1,2]
# print(a is b)
# a=[1,2]
# b=a
# print(a is b)
# a=[2,3]
# b=a
# print(a is not b)
a=None
print(a is None)
# Out:
# True

# %%
# Membership Operators
# a="apple"
# print("a" in a)
# a="rajesh"
# print("r" not in a)
num=[1,2,3,4,5]
print(5 in num)
# Out:
# True

# %%
# a="helloworld"
# b="helloworld"
# print(a is b)
# Out:
# True
