# %%
# A1. Even or Odd
num = int(input("Enter number: "))

if num % 2 == 0:
    print("Even")
else:
    print("Odd")

# %%
# A2. Grade based on marks
marks = int(input("Enter marks: "))

if marks >= 90:
    print("Grade A")
elif marks >= 75:
    print("Grade B")
elif marks >= 60:
    print("Grade C")
elif marks >= 50:
    print("Grade D")
else:
    print("Grade F")

# %%
# A3. Positive, Negative, or Zero
num = int(input("Enter number: "))

if num > 0:
    print("Positive")
elif num < 0:
    print("Negative")
else:
    print("Zero")

# %%
# A4. Leap Year
year = int(input("Enter year: "))

if (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0):
    print("Leap Year")
else:
    print("Not Leap Year")

# %%
# A5. Smallest of Three Numbers
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
c = int(input("Enter third number: "))

smallest = min(a, b, c)
print("Smallest:", smallest)

# %%
# A6. Password Validator (Python123)
password = input("Enter password: ")

if password == "Python123":
    print("Access Granted")
else:
    print("Access Denied")

# %%
# A7. Simple Calculator
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
op = input("Enter operator (+, -, *, /): ")

if op == "+":
    print(a + b)
elif op == "-":
    print(a - b)
elif op == "*":
    print(a * b)
elif op == "/":
    print(a / b)
else:
    print("Invalid operator")

# %%
# A8. Voting Check
age = int(input("Enter age: "))

if age >= 18:
    print("Eligible to vote")
else:
    print("Not eligible")

# %%
# A9. Vowel or Consonant
ch = input("Enter character: ")

if ch.lower() in "aeiou":
    print("Vowel")
else:
    print("Consonant")

# %%
# A10. Weekend or Weekday
day = input("Enter day: ")

if day.lower() in ["saturday", "sunday"]:
    print("Weekend")
else:
    print("Weekday")

# %%
# List Operations
l = [1, 22, 3, 44, 55, 6, 11, 1200]

# %%
# B1. Insert 4 at 6th index
l.insert(6, 4)
print(l)

# %%
# B2. Remove value 
l.remove(44)
print(l)

# %%
# B3. Append 88
l.append(88)
print(l)

# %%
# B4. Remove element at 2nd index
l.pop(2)
print(l)

# %%
# B5. Merge lists
m = [1, 2, 3, 546]
new_list = l + m
print(new_list)

# %%
# String Operations
s = "HelloWorld"

# %%
# C1. Insert "Python" at 6th index
s = s[:6] + "Python" + s[6:]
print(s)

# %%
# C2. Remove "World"
s = s.replace("World", "")
print(s)

# %%
# C3. Append "2024"
s = s + "2024"
print(s)

# %%
# C4. Remove character at 2nd index
s = s[:2] + s[3:]
print(s)

# %%
# C5. Concatenate with t = "Programming"
t = "Programming"
s = s + t
print(s)

# %%
# D1. Grade System
marks = int(input("Enter marks: "))

if marks >= 50:
    print("Pass")
else:
    print("Fail")

# %%
# D2. Vowel or Consonant
ch = input("Enter character: ")

if ch in "aeiouAEIOU":
    print("Vowel")
else:
    print("Consonant")

# %%
# D3. Login System
username = input("Enter username: ")
password = input("Enter password: ")

if username == "admin" and password == "1234":
    print("Login Successful")
else:
    print("Login Failed")
